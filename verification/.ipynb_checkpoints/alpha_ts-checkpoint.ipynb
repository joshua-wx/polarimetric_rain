# %%
from glob import glob
from datetime import datetime
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from tqdm import tqdm
import cftime

import pyart
from netCDF4 import Dataset

# %%
radar_id = '02'
date_str = '20181120'
dp_path = f'/g/data/rq0/admin/dp-rain-verification-testing/cfradial/{radar_id}/{date_str}'
dp_ffn_list = sorted(glob(dp_path + '/*.nc'))
print(dp_ffn_list)
time_fmt = mdates.DateFormatter('%H:%M')
# Out:
# ['/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_000046.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_000643.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_001246.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_001846.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_003043.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_003643.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_004243.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_004846.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_005446.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_010043.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_010646.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_011246.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_011843.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_012443.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_013046.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_013643.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_014843.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_015446.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_020043.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_020646.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_021246.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_021843.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_022446.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_023046.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_023643.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_024243.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_024846.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_025443.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_030043.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_030643.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_031246.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_031843.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_033046.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_033646.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_034246.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_034843.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_035443.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_040043.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_040646.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_041246.vol.nc', '/g/data/rq0/admin/dp-rain-verification-testing/cfradial/02/20181120/02_20181120_041846.vol.nc', '/g/data/rq0/admin/dp- ...

# %%
td_ts = []
alpha_ts = []
alpha_method_ts = []
system_phase_ts = []

for dp_ffn in tqdm(dp_ffn_list, total=len(dp_ffn_list)):
    with Dataset(dp_ffn) as radar:
        td_ts.append(cftime.num2pydate(radar['time'][0], radar['time'].units))
        alpha_ts.append(radar['specific_attenuation'].alpha)
        alpha_method_ts.append(radar['specific_attenuation'].alpha_method)
        system_phase_ts.append(radar['PHIDP_B'].system_phase)
# Out:
# 100%|██████████| 216/216 [01:10<00:00,  3.07it/s]

# %%
plt.figure(figsize=[10,8])

ax1 = plt.subplot(211)
ax1.set_title(f'Analysis for radar:{radar_id}, date:{date_str}')
ax1.plot(td_ts, alpha_ts, 'b-')
ax1.set_xlabel('Time(UTC)')
ax1.set_ylabel(r"$ \alpha (dB deg^{-1})$", color='b')
ax1.xaxis.set_major_formatter(time_fmt)
ax1.grid()
ax1a = ax1.twinx()
ax1a.plot(td_ts, alpha_method_ts, 'r-')
ax1a.set_ylim(0.9,5.1)
ax1a.set_ylabel("Alpha Technique (Zhang et al. 2020)", color='r')
ax1a.xaxis.set_major_formatter(time_fmt)

ax2 = plt.subplot(212)
ax2.plot(td_ts, system_phase_ts, 'k-')
ax2.set_xlabel('Time(UTC)')
ax2.set_ylabel("System Phase (deg)")
ax2.xaxis.set_major_formatter(time_fmt)
ax2.grid()
